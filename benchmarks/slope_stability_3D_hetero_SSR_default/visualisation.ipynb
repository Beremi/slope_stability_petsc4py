# %% [markdown]
# # 3D heterogeneous SSR default (visualisation)
#
# This notebook is generated from the shared benchmark notebook framework.
#
# - Benchmark folder: `slope_stability_3D_hetero_SSR_default`
# - Original MATLAB driver: `slope_stability_3D_hetero_SSR.m`
# - Comparison kind: `continuation`
# - Notebook family: `3d_continuation`

# %%
from pathlib import Path
import sys

ROOT = next(
    path for path in [Path.cwd(), *Path.cwd().parents]
    if (path / "benchmarks").is_dir() and (path / "src").is_dir()
)
if str(ROOT / "benchmarks") not in sys.path:
    sys.path.insert(0, str(ROOT / "benchmarks"))

import notebook_support as nb

CASE_TOML = ROOT / "benchmarks" / "slope_stability_3D_hetero_SSR_default" / "case.toml"
CASE_DIR = CASE_TOML.parent

# %%
metadata = nb.load_case_metadata(CASE_TOML)
sections = nb.load_case_sections(CASE_TOML)
materials = nb.load_case_materials(CASE_TOML)

print(nb.summarize_sections(sections, materials))
metadata
# Out:
# Editable runtime sections:
# - problem: analysis, case, davis_type, dimension, elem_type, mesh_path, name, seepage, variant
# - execution: constitutive_mode, mpi_distribute_by_nodes, node_ordering
# - continuation: d_lambda_diff_scaled_min, d_lambda_init, d_lambda_min, init_newton_stopping_criterion, init_newton_stopping_tol, lambda_init, method, omega_max, step_max
# - newton: it_damp_max, it_max, r_min, stopping_criterion, stopping_tol, tol
# - linear_solver: compiled_outer, deflation_basis_tolerance, max_iterations, pc_backend, pc_hypre_coarsen_type, pc_hypre_interp_type, petsc_opt, print_level, recycle_preconditioner, solver_type, threads, tolerance, use_as_preconditioner
# - export: custom_debug_name, history_name, solution_name, write_custom_debug_bundle, write_history_json, write_solution_vtu
# {'case_toml': PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/slope_stability_3D_hetero_SSR_default/case.toml'),
#  'case_dir': PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/slope_stability_3D_hetero_SSR_default'),
#  'benchmark_name': 'slope_stability_3D_hetero_SSR_default',
#  'benchmark': {'title': '3D heterogeneous SSR default',
#   'matlab_script': 'slope_stability_3D_hetero_SSR.m',
#   'comparison_kind': 'continuation',
#   'mpi_ranks': 8,
#   'suite': False},
#  'notebook': {'family': '3d_continuation',
#   'jupyter_backend': 'client',
#   'nonlinear_surface_subdivision': 2,
#   'surface_decimate_reduction': 0.75,
#   'boundary_edge_overlay': False,
#   'slice_planes_y': [35.0],
#   'slice_planes_z': [43.30127019, 64.95190529],
#   'strain_clim_scale_max': 0.25},
#  'problem': {'name': 'slope_stability_3D_hetero_SSR_default',
#   'case': '3d_hetero_ssr',
#   'analysis': 'ssr',
#   'dimension': 3,
#   'variant': 'hetero',
#   'elem_type': 'P4',
#   'davis_type': 'B',
#   'seepage': False,
#   'mesh_path': '../../meshes/3d_hetero_ssr/SSR_hetero_ada_L1.msh'},
#  'title': '3D heterogeneous SSR default',
#  'matlab_script': 'slope_stability_3D_hetero_SSR.m',
#  'comparison_kind': 'continuation',
#  'mpi_ranks': 8,
#  'family': '3d_continuation',
#  'jupyter_backend': 'client',
#  'nonlinear_surface_subdivision': 2,
#  'surface_decimate_reduction': 0.75,
#  'boundary_edge_overlay': False}

# %% [markdown]
# ## Artifact Source
#
# This notebook is post-processing oriented. By default it reuses the artifacts from `simulation.ipynb`.

# %% [markdown]
# ## Visualisation Workflow
#
# These notebooks are post-processing oriented. By default they reuse the artifacts written by
# `simulation.ipynb`, so rerunning the solver is only necessary when the stored outputs are missing or stale.
# The cells below are grouped in a consistent order so comparable benchmarks expose the same kinds of views:
#
# 1. geometry and material layout
# 2. hydraulic fields when seepage is part of the problem
# 3. mechanical response for LL and SSR continuation cases
# 4. configured slice views when a benchmark defines MATLAB-style planes

# %% [markdown]
# ## Controls
#
# Use the overrides in the next cell to switch artifact reuse behavior or tune the interactive PyVista previews.
# Keep `RUN_MODE = "reuse"` for normal post-processing. The surface controls only affect display tessellation and
# preview simplification; they do not change the stored finite-element solution.

# %%
RUN_LABEL = "simulation"
RUN_MODE = "reuse"  # change to "auto" only if you want this notebook to fall back to a smoke solve
EXECUTION_PROFILE = "smoke"
MPI_RANKS = None
JUPYTER_BACKEND_OVERRIDE = None  # set to "client", "trame", "server", "html", or "static"; None uses case.toml
SURFACE_SUBDIVISION_OVERRIDE = None  # set to 0, 1, 2, 3, or 4 to trade preview fidelity for speed; None uses case.toml default
SURFACE_DECIMATE_REDUCTION_OVERRIDE = None  # set e.g. 0.5, 0.75, or 0.9 for a lighter preview mesh
BOUNDARY_EDGE_OVERLAY_OVERRIDE = None  # set to True to draw coarse tetra boundary edges over smooth surface colors

# %%
execution = nb.ensure_notebook_artifacts(
    case_toml=CASE_TOML,
    sections=sections,
    materials=materials,
    run_label=RUN_LABEL,
    run_mode=RUN_MODE,
    execution_profile=EXECUTION_PROFILE,
    mpi_ranks=MPI_RANKS,
    root=CASE_DIR,
)
GENERATED_CONFIG = execution.generated_config
ACTIVE_CONFIG = execution.active_config
OUT_DIR = execution.out_dir
execution
# Out:
# NotebookExecution(out_dir=PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/slope_stability_3D_hetero_SSR_default/artifacts/simulation'), active_config=PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/slope_stability_3D_hetero_SSR_default/artifacts/simulation/generated_case.toml'), generated_config=PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/slope_stability_3D_hetero_SSR_default/artifacts/simulation/generated_case.toml'), reused_existing=True, source_label='artifacts/simulation', run_result=None)

# %%
artifacts = nb.load_run_artifacts(OUT_DIR)
nb.show_run_summary(artifacts)
print("")
print("Artifact source:", execution.source_label)
print("Active config:", ACTIVE_CONFIG)
print("")
print("Saved files:")
for path in nb.list_saved_files(OUT_DIR):
    print(" ", path.relative_to(ROOT))
# Out:
# {
#   "timestamp": "2026-04-04T04:49:02",
#   "python_version": "petsc driver",
#   "runtime_seconds": 884.2053421540186,
#   "mpi_size": 8,
#   "mesh_nodes": 208549,
#   "mesh_elements": 18419,
#   "unknowns": 616322,
#   "analysis": "ssr",
#   "solver_type": "PETSC_MATLAB_DFGMRES_HYPRE_NULLSPACE",
#   "step_count": 9
# }
#
# {
#   "mesh_file": "/home/beremi/repos/slope_stability-1/meshes/3d_hetero_ssr/SSR_hetero_ada_L1.msh",
#   "coord_shape": [
#     3,
#     208549
#   ],
#   "elem_shape": [
#     35,
#     18419
#   ],
#   "surf_shape": [
#     15,
#     6325
#   ]
# }
#
# {
#   "constitutive": {
#     "reduction": 1.754619552521035,
#     "stress": 6.959091506432742,
#     "stress_tangent": 2.2795385075733066,
#     "build_F": 26.498994609573856,
#     "build_F_K_tangent": 0.0,
#     "build_tangent_local": 43.7947063378524,
#     "local_strain": 6.1147738674189895,
#     "local_constitutive": 3.120399172184989,
#     "local_constitutive_comm": 0.0,
#     "local_force_assembly": 18.964323714608327,
#     "local_force_gather": 7.906691338634118,
#     "potential": 0.0
#   },
#   "linear": {
#     "init_linear_iterations": 95,
#     "init_linear_solve_time": 45.443435727385804,
#     "init_linear_preconditioner_time": 7.385944464476779,
#     "init_linear_orthogonalization_time": 7.279598547145724,
#     "attempt_linear_iterations_total": 1027,
#     "attempt_linear_solve_time_total": 504.9995825961232,
#     "attempt_linear_preconditioner_time_total": 36.670249356888235,
#     "attempt_linear_orthogonalization_time_total": 98.27087089186534,
#     "pc_backend": "pmg_shell",
#     "preconditioner_matrix_source": "tangent",
#     "preconditioner_matrix_policy": "current",
#     "preconditioner_rebuild_policy": "every_newton",
#     "preconditioner_rebuild_interval": 1,
#     "preconditioner_rebuild_count": 81,
#     "preconditioner_reuse_count": 0,
#     "preconditioner_age_max": 0,
#     "preconditioner_setup_time_last": 0.5420132109429687,
#     "preconditioner_setup_time_total": 44.056193821365014,
#     "preconditioner_apply_time_last": 0.3695991509594023,
#     "preconditioner_apply_time_total": 434.7565102186054,
#     "preconditioner_last_rebuild_reason": "current_policy",
#     "preconditioner_age_current": 0,
#     "manualmg_levels": 3,
#     "manualmg_level_orders": [
#       1,
#       2,
#       4
#     ],
#     "manualmg_level_global_sizes": [
#       10859,
#       80362,
#       616322
#     ],
#     "manualmg_level_owned_ranges": [
#       [
#         0,
#         1364
#       ],
#       [
#         0,
#         10015
#       ],
#       [
#         0,
#         77356
#       ]
#     ],
#     "manualmg_transfer_shapes": [
#       [
#         80362,
#         10859
#       ],
#       [
#         616322,
#         80362
#       ]
#     ],
#     "manualmg_restriction_shapes": [
#       [
#         10859,
#         80362
#       ],
#       [
#         80362,
#         616322
#       ]
#     ],
#     "manualmg_coarse_ksp_type": "preonly",
#     "manualmg_coarse_pc_type": "hypre",
#     "manualmg_coarse_iterations": 1,
#     "manualmg_coarse_converged_reason": 4,
#     "manualmg_coarse_ksp_rtol": 1e-10,
#     "manualmg_coarse_ksp_max_it": 200,
#     "manualmg_coarse_full_system": false,
#     "manualmg_coarse_operator_source": "galerkin_free",
#     "manualmg_coarse_solve_global_size": 10859,
#     "manualmg_coarse_block_size": 1,
#     "manualmg_apply_count": 1027,
#     "manualmg_fine_pre_smoother_time_total_s": 166.08667635405436,
#     "manualmg_fine_post_smoother_time_total_s": 176.54256668593735,
#     "manualmg_mid_pre_smoother_time_total_s": 8.179323701187968,
#     "manualmg_mid_post_smoother_time_total_s": 7.479492621263489,
#     "manualmg_restrict_fine_to_mid_time_total_s": 1.2103863009251654,
#     "manualmg_restrict_mid_to_coarse_time_total_s": 0.13748949579894543,
#     "manualmg_prolong_coarse_to_mid_time_total_s": 0.11337557784281671,
#     "manualmg_prolong_mid_to_fine_time_total_s": 1.719835783354938,
#     "manualmg_fine_residual_time_total_s": 33.58038105349988,
#     "manualmg_mid_residual_time_total_s": 1.074058511061594,
#     "manualmg_vector_sum_time_total_s": 0.22997387615032494,
#     "manualmg_coarse_hypre_time_total_s": 1.4256099900230765,
#     "manualmg_fine_smoother_iterations_total": 6162,
#     "manualmg_mid_smoother_iterations_total": 6162,
#     "manualmg_coarse_ksp_iterations_total": 1027,
#     "manualmg_coarse_solve_count": 1027,
#     "manualmg_last_fine_pre_smoother_time_s": 0.15438374620862305,
#     "manualmg_last_fine_post_smoother_time_s": 0.16330823418684304,
#     "manualmg_last_mid_pre_smoother_time_s": 0.007614443078637123,
#     "manualmg_last_mid_post_smoother_time_s": 0.006863025948405266,
#     "manualmg_last_restrict_fine_to_mid_time_s": 0.0011394189205020666,
#     "manualmg_last_restrict_mid_to_coarse_time_s": 0.00012141186743974686,
#     "manualmg_last_prolong_coarse_to_mid_time_s": 0.00010297703556716442,
#     "manualmg_last_prolong_mid_to_fine_time_s": 0.0016017230227589607,
#     "manualmg_last_fine_residual_time_s": 0.031260544899851084,
#     "manualmg_last_mid_residual_time_s": 0.0010655280202627182,
#     "manualmg_last_vector_sum_time_s": 0.00019552395679056644,
#     "manualmg_last_coarse_hypre_time_s": 0.0012568540405482054,
#     "manualmg_last_coarse_iterations": 1,
#     "manualmg_coarse_hypre_type": "boomeramg",
#     "manualmg_coarse_pc_hypre_boomeramg_max_iter": "1",
#     "manualmg_coarse_pc_hypre_boomeramg_tol": "0.0",
#     "manualmg_coarse_pc_hypre_boomeramg_coarsen_type": "HMIS",
#     "manualmg_coarse_pc_hypre_boomeramg_interp_type": "ext+i",
#     "manualmg_coarse_pc_hypre_boomeramg_P_max": "4",
#     "manualmg_coarse_pc_hypre_boomeramg_strong_threshold": "0.5",
#     "manualmg_coarse_pc_hypre_boomeramg_grid_sweeps_all": "1",
#     "manualmg_coarse_pc_hypre_boomeramg_cycle_type": "V",
#     "manualmg_coarse_pc_hypre_boomeramg_agg_nl": "0",
#     "manualmg_coarse_iteration_count_mode": "coarse_ksp_iterations_only",
#     "manualmg_level_1_ksp_type": "richardson",
#     "manualmg_level_1_pc_type": "sor",
#     "manualmg_level_1_iterations": 3,
#     "manualmg_level_1_converged_reason": 4,
#     "manualmg_level_2_ksp_type": "richardson",
#     "manualmg_level_2_pc_type": "sor",
#     "manualmg_level_2_iterations": 3,
#     "manualmg_level_2_converged_reason": 4,
#     "manualmg_mid_ksp_type": "richardson",
#     "manualmg_mid_pc_type": "sor",
#     "manualmg_mid_iterations": 3,
#     "manualmg_fine_ksp_type": "richardson",
#     "manualmg_fine_pc_type": "sor",
#     "manualmg_fine_iterations": 3,
#     "manualmg_setup_time_s": 0.5420132109429687,
#     "manualmg_last_phase": "solve",
#     "manualmg_last_pc_apply_time_s": 0.3695991509594023
#   },
#   "continuation_total_wall_time": 884.2047838959843
# }
#
# Artifact source: artifacts/simulation
# Active config: /home/beremi/repos/slope_stability-1/benchmarks/slope_stability_3D_hetero_SSR_default/artifacts/simulation/generated_case.toml
#
# Saved files:
#   benchmarks/slope_stability_3D_hetero_SSR_default/artifacts/simulation/data/petsc_run.npz
#   benchmarks/slope_stability_3D_hetero_SSR_default/artifacts/simulation/data/run_info.json
#   benchmarks/slope_stability_3D_hetero_SSR_default/artifacts/simulation/exports/final_solution.vtu
#   benchmarks/slope_stability_3D_hetero_SSR_default/artifacts/simulation/generated_case.toml

# %% [markdown]
# ## Continuation Summary
#
# MATLAB-style continuation and timing summaries rebuilt from the PETSc artifacts.

# %%
_ = nb.plot_convergence_dashboard(artifacts)
_ = nb.plot_timing_breakdown(artifacts)

# %% [markdown]
# ## Interactive 3D Views
#
# These cells use PyVista when the optional `.[viz]` extras are available. In a non-viz environment they return a clear status message instead of failing import-time.

# %%
nb.viz_support_status()
# Out:
# {'pyvista': True, 'ipywidgets': True, 'trame': True}

# %% [markdown]
# ## Geometry And Materials
#
# Start with the boundary geometry to confirm the mesh, orientation, and free-surface shape before looking at hydraulic or mechanical fields.

# %%
_ = nb.show_3d_mesh_view(artifacts, ACTIVE_CONFIG, surface_subdivision=0, surface_decimate_reduction=SURFACE_DECIMATE_REDUCTION_OVERRIDE, jupyter_backend=JUPYTER_BACKEND_OVERRIDE)
# Out:
# Widget(value='<iframe src="http://localhost:37849/index.html?ui=P_0x7fd04025a850_5&reconnect=auto" class="pyvi…

# %% [markdown]
# ## Mechanical Response
#
# These continuation benchmarks focus on deformation. Displacement is shown on the warped surface and deviatoric strain highlights localization.

# %%
_ = nb.show_3d_displacement_view(artifacts, ACTIVE_CONFIG, surface_subdivision=SURFACE_SUBDIVISION_OVERRIDE, surface_decimate_reduction=SURFACE_DECIMATE_REDUCTION_OVERRIDE, boundary_edge_overlay=BOUNDARY_EDGE_OVERLAY_OVERRIDE, jupyter_backend=JUPYTER_BACKEND_OVERRIDE)
# Out:
# Widget(value='<iframe src="http://localhost:37849/index.html?ui=P_0x7fd1cd695a90_6&reconnect=auto" class="pyvi…

# %%
_ = nb.show_3d_deviatoric_surface_view(artifacts, ACTIVE_CONFIG, surface_subdivision=SURFACE_SUBDIVISION_OVERRIDE, surface_decimate_reduction=SURFACE_DECIMATE_REDUCTION_OVERRIDE, boundary_edge_overlay=BOUNDARY_EDGE_OVERLAY_OVERRIDE, jupyter_backend=JUPYTER_BACKEND_OVERRIDE)
# Out:
# Widget(value='<iframe src="http://localhost:37849/index.html?ui=P_0x7fd0407cce10_7&reconnect=auto" class="pyvi…

# %% [markdown]
# ## Slice Views
#
# When slice planes are configured for the benchmark, this cell reconstructs the MATLAB-style cross-sections from the same VTU fields.

# %%
_ = nb.show_3d_deviatoric_slices(
    artifacts,
    ACTIVE_CONFIG,
    slice_planes_x=[],
    slice_planes_y=[35.0],
    slice_planes_z=[43.30127019, 64.95190529],
    clim_scale_max=0.25,
    jupyter_backend=JUPYTER_BACKEND_OVERRIDE,
)
# Out:
# Widget(value='<iframe src="http://localhost:37849/index.html?ui=P_0x7fd040165310_8&reconnect=auto" class="pyvi…
