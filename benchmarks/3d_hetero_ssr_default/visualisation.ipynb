# %% [markdown]
# # 3D heterogeneous SSR default (visualisation)
#
# This notebook is generated from the shared benchmark notebook framework.
#
# - Benchmark folder: `3d_hetero_ssr_default`
# - Original MATLAB driver: `slope_stability_3D_hetero_SSR.m`
# - Comparison kind: `continuation`
# - Notebook family: `3d_continuation`

# %%
from pathlib import Path
import sys

ROOT = next(
    path for path in [Path.cwd(), *Path.cwd().parents]
    if (path / "benchmarks").is_dir() and (path / "src").is_dir()
)
if str(ROOT / "benchmarks") not in sys.path:
    sys.path.insert(0, str(ROOT / "benchmarks"))

import notebook_support as nb

CASE_TOML = ROOT / "benchmarks" / "3d_hetero_ssr_default" / "case.toml"
CASE_DIR = CASE_TOML.parent

# %%
metadata = nb.load_case_metadata(CASE_TOML)
sections = nb.load_case_sections(CASE_TOML)
materials = nb.load_case_materials(CASE_TOML)

print(nb.summarize_sections(sections, materials))
metadata
# Out:
# Editable runtime sections:
# - problem: analysis, case, davis_type, dimension, elem_type, mesh_path, name, seepage, variant
# - execution: constitutive_mode, mpi_distribute_by_nodes, node_ordering
# - continuation: d_lambda_diff_scaled_min, d_lambda_init, d_lambda_min, init_newton_stopping_criterion, init_newton_stopping_tol, lambda_init, method, omega_max, step_max
# - newton: it_damp_max, it_max, r_min, stopping_criterion, stopping_tol, tol
# - linear_solver: compiled_outer, deflation_basis_tolerance, max_iterations, pc_backend, pc_hypre_coarsen_type, pc_hypre_interp_type, petsc_opt, print_level, recycle_preconditioner, solver_type, threads, tolerance, use_as_preconditioner
# - export: custom_debug_name, history_name, solution_name, write_custom_debug_bundle, write_history_json, write_solution_vtu
# {'case_toml': PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/3d_hetero_ssr_default/case.toml'),
#  'case_dir': PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/3d_hetero_ssr_default'),
#  'benchmark_name': '3d_hetero_ssr_default',
#  'benchmark': {'title': '3D heterogeneous SSR default',
#   'matlab_script': 'slope_stability_3D_hetero_SSR.m',
#   'comparison_kind': 'continuation',
#   'mpi_ranks': 8,
#   'suite': False},
#  'notebook': {'family': '3d_continuation',
#   'jupyter_backend': 'client',
#   'nonlinear_surface_subdivision': 0,
#   'surface_decimate_reduction': 0.75,
#   'boundary_edge_overlay': False,
#   'slice_planes_y': [35.0],
#   'slice_planes_z': [43.30127019, 64.95190529],
#   'strain_clim_scale_max': 0.25},
#  'problem': {'name': '3d_hetero_ssr_default',
#   'case': '3d_hetero_ssr',
#   'analysis': 'ssr',
#   'dimension': 3,
#   'variant': 'hetero',
#   'elem_type': 'P4',
#   'davis_type': 'B',
#   'seepage': False,
#   'mesh_path': '../../meshes/3d_hetero_ssr/SSR_hetero_ada_L1.msh'},
#  'title': '3D heterogeneous SSR default',
#  'matlab_script': 'slope_stability_3D_hetero_SSR.m',
#  'comparison_kind': 'continuation',
#  'mpi_ranks': 8,
#  'family': '3d_continuation',
#  'jupyter_backend': 'client',
#  'nonlinear_surface_subdivision': 0,
#  'surface_decimate_reduction': 0.75,
#  'boundary_edge_overlay': False}

# %% [markdown]
# ## Artifact Source
#
# This notebook is post-processing oriented. By default it reuses the artifacts from `simulation.ipynb`.

# %%
RUN_LABEL = "simulation"
RUN_MODE = "reuse"  # change to "auto" only if you want this notebook to fall back to a smoke solve
EXECUTION_PROFILE = "smoke"
MPI_RANKS = None
JUPYTER_BACKEND_OVERRIDE = None  # set to "client", "trame", "server", "html", or "static"; None uses case.toml
SURFACE_SUBDIVISION_OVERRIDE = None  # set to 1, 2, 3, or 4 to trade quality for speed; None uses case.toml default
SURFACE_DECIMATE_REDUCTION_OVERRIDE = None  # set e.g. 0.5, 0.75, or 0.9 for a lighter preview mesh
BOUNDARY_EDGE_OVERLAY_OVERRIDE = None  # set to True to draw coarse tetra boundary edges over smooth surface colors

# %%
execution = nb.ensure_notebook_artifacts(
    case_toml=CASE_TOML,
    sections=sections,
    materials=materials,
    run_label=RUN_LABEL,
    run_mode=RUN_MODE,
    execution_profile=EXECUTION_PROFILE,
    mpi_ranks=MPI_RANKS,
    root=CASE_DIR,
)
GENERATED_CONFIG = execution.generated_config
ACTIVE_CONFIG = execution.active_config
OUT_DIR = execution.out_dir
execution
# Out:
# NotebookExecution(out_dir=PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/3d_hetero_ssr_default/artifacts/simulation'), active_config=PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/3d_hetero_ssr_default/artifacts/simulation/generated_case.toml'), generated_config=PosixPath('/home/beremi/repos/slope_stability-1/benchmarks/3d_hetero_ssr_default/artifacts/simulation/generated_case.toml'), reused_existing=True, source_label='artifacts/simulation', run_result=None)

# %%
artifacts = nb.load_run_artifacts(OUT_DIR)
nb.show_run_summary(artifacts)
print("")
print("Artifact source:", execution.source_label)
print("Active config:", ACTIVE_CONFIG)
print("")
print("Saved files:")
for path in nb.list_saved_files(OUT_DIR):
    print(" ", path.relative_to(ROOT))
# Out:
# {
#   "timestamp": "2026-04-01T21:14:39",
#   "python_version": "petsc driver",
#   "runtime_seconds": 1102.2042346110102,
#   "mpi_size": 8,
#   "mesh_nodes": 208549,
#   "mesh_elements": 18419,
#   "unknowns": 616322,
#   "analysis": "ssr",
#   "solver_type": "PETSC_MATLAB_DFGMRES_HYPRE_NULLSPACE",
#   "step_count": 9
# }
#
# {
#   "mesh_file": "/home/beremi/repos/slope_stability-1/meshes/3d_hetero_ssr/SSR_hetero_ada_L1.msh",
#   "coord_shape": [
#     3,
#     208549
#   ],
#   "elem_shape": [
#     35,
#     18419
#   ],
#   "surf_shape": [
#     15,
#     6325
#   ]
# }
#
# {
#   "constitutive": {
#     "reduction": 1.994646777282469,
#     "stress": 7.860843533533625,
#     "stress_tangent": 2.4199528937460855,
#     "build_F": 28.556815533316694,
#     "build_F_K_tangent": 0.0,
#     "build_tangent_local": 48.32511423469987,
#     "local_strain": 6.9125719734001905,
#     "local_constitutive": 3.4320888930233195,
#     "local_constitutive_comm": 0.0,
#     "local_force_assembly": 21.577833643415943,
#     "local_force_gather": 7.7064996965928,
#     "potential": 0.0
#   },
#   "linear": {
#     "init_linear_iterations": 95,
#     "init_linear_solve_time": 47.62249022000469,
#     "init_linear_preconditioner_time": 7.70657190179918,
#     "init_linear_orthogonalization_time": 7.530688707949594,
#     "attempt_linear_iterations_total": 1299,
#     "attempt_linear_solve_time_total": 663.1357945320196,
#     "attempt_linear_preconditioner_time_total": 40.46890947269276,
#     "attempt_linear_orthogonalization_time_total": 132.1803565438604,
#     "pc_backend": "pmg_shell",
#     "preconditioner_matrix_source": "tangent",
#     "preconditioner_matrix_policy": "current",
#     "preconditioner_rebuild_policy": "every_newton",
#     "preconditioner_rebuild_interval": 1,
#     "preconditioner_rebuild_count": 88,
#     "preconditioner_reuse_count": 0,
#     "preconditioner_age_max": 0,
#     "preconditioner_setup_time_last": 0.5419048570329323,
#     "preconditioner_setup_time_total": 48.17548137449194,
#     "preconditioner_apply_time_last": 0.39585304190404713,
#     "preconditioner_apply_time_total": 558.3629769398831,
#     "preconditioner_last_rebuild_reason": "current_policy",
#     "preconditioner_age_current": 0,
#     "manualmg_levels": 3,
#     "manualmg_level_orders": [
#       1,
#       2,
#       4
#     ],
#     "manualmg_level_global_sizes": [
#       10859,
#       80362,
#       616322
#     ],
#     "manualmg_level_owned_ranges": [
#       [
#         0,
#         1364
#       ],
#       [
#         0,
#         10015
#       ],
#       [
#         0,
#         77356
#       ]
#     ],
#     "manualmg_transfer_shapes": [
#       [
#         80362,
#         10859
#       ],
#       [
#         616322,
#         80362
#       ]
#     ],
#     "manualmg_restriction_shapes": [
#       [
#         10859,
#         80362
#       ],
#       [
#         80362,
#         616322
#       ]
#     ],
#     "manualmg_coarse_ksp_type": "preonly",
#     "manualmg_coarse_pc_type": "hypre",
#     "manualmg_coarse_iterations": 1,
#     "manualmg_coarse_converged_reason": 4,
#     "manualmg_coarse_ksp_rtol": 1e-10,
#     "manualmg_coarse_ksp_max_it": 200,
#     "manualmg_coarse_full_system": false,
#     "manualmg_coarse_operator_source": "galerkin_free",
#     "manualmg_coarse_solve_global_size": 10859,
#     "manualmg_coarse_block_size": 1,
#     "manualmg_apply_count": 1299,
#     "manualmg_fine_pre_smoother_time_total_s": 216.79279808851425,
#     "manualmg_fine_post_smoother_time_total_s": 230.87976525933482,
#     "manualmg_mid_pre_smoother_time_total_s": 10.649789630435407,
#     "manualmg_mid_post_smoother_time_total_s": 9.625090745743364,
#     "manualmg_restrict_fine_to_mid_time_total_s": 1.565585698117502,
#     "manualmg_restrict_mid_to_coarse_time_total_s": 0.18002307298593223,
#     "manualmg_prolong_coarse_to_mid_time_total_s": 0.15417231351602823,
#     "manualmg_prolong_mid_to_fine_time_total_s": 1.9707776532741264,
#     "manualmg_fine_residual_time_total_s": 44.23485596536193,
#     "manualmg_mid_residual_time_total_s": 1.3756818620022386,
#     "manualmg_vector_sum_time_total_s": 0.3003239524550736,
#     "manualmg_coarse_hypre_time_total_s": 1.8128248911816627,
#     "manualmg_fine_smoother_iterations_total": 7794,
#     "manualmg_mid_smoother_iterations_total": 7794,
#     "manualmg_coarse_ksp_iterations_total": 1299,
#     "manualmg_coarse_solve_count": 1299,
#     "manualmg_last_fine_pre_smoother_time_s": 0.16411590995267034,
#     "manualmg_last_fine_post_smoother_time_s": 0.17378578195348382,
#     "manualmg_last_mid_pre_smoother_time_s": 0.007461759028956294,
#     "manualmg_last_mid_post_smoother_time_s": 0.006553763058036566,
#     "manualmg_last_restrict_fine_to_mid_time_s": 0.0012367250164970756,
#     "manualmg_last_restrict_mid_to_coarse_time_s": 0.0001297680428251624,
#     "manualmg_last_prolong_coarse_to_mid_time_s": 0.0001054919557645917,
#     "manualmg_last_prolong_mid_to_fine_time_s": 0.0017121239798143506,
#     "manualmg_last_fine_residual_time_s": 0.037497897050343454,
#     "manualmg_last_mid_residual_time_s": 0.0010694649536162615,
#     "manualmg_last_vector_sum_time_s": 0.00020708609372377396,
#     "manualmg_last_coarse_hypre_time_s": 0.0013131810119375587,
#     "manualmg_last_coarse_iterations": 1,
#     "manualmg_coarse_hypre_type": "boomeramg",
#     "manualmg_coarse_pc_hypre_boomeramg_max_iter": "1",
#     "manualmg_coarse_pc_hypre_boomeramg_tol": "0.0",
#     "manualmg_coarse_pc_hypre_boomeramg_coarsen_type": "HMIS",
#     "manualmg_coarse_pc_hypre_boomeramg_interp_type": "ext+i",
#     "manualmg_coarse_pc_hypre_boomeramg_P_max": "4",
#     "manualmg_coarse_pc_hypre_boomeramg_strong_threshold": "0.5",
#     "manualmg_coarse_pc_hypre_boomeramg_grid_sweeps_all": "1",
#     "manualmg_coarse_pc_hypre_boomeramg_cycle_type": "V",
#     "manualmg_coarse_pc_hypre_boomeramg_agg_nl": "0",
#     "manualmg_coarse_iteration_count_mode": "coarse_ksp_iterations_only",
#     "manualmg_level_1_ksp_type": "richardson",
#     "manualmg_level_1_pc_type": "sor",
#     "manualmg_level_1_iterations": 3,
#     "manualmg_level_1_converged_reason": 4,
#     "manualmg_level_2_ksp_type": "richardson",
#     "manualmg_level_2_pc_type": "sor",
#     "manualmg_level_2_iterations": 3,
#     "manualmg_level_2_converged_reason": 4,
#     "manualmg_mid_ksp_type": "richardson",
#     "manualmg_mid_pc_type": "sor",
#     "manualmg_mid_iterations": 3,
#     "manualmg_fine_ksp_type": "richardson",
#     "manualmg_fine_pc_type": "sor",
#     "manualmg_fine_iterations": 3,
#     "manualmg_setup_time_s": 0.5419048570329323,
#     "manualmg_last_phase": "solve",
#     "manualmg_last_pc_apply_time_s": 0.39585304190404713
#   },
#   "continuation_total_wall_time": 1102.2038887690287
# }
#
# Artifact source: artifacts/simulation
# Active config: /home/beremi/repos/slope_stability-1/benchmarks/3d_hetero_ssr_default/artifacts/simulation/generated_case.toml
#
# Saved files:
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/data/petsc_run.npz
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/data/progress.jsonl
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/data/progress_latest.json
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/data/run_info.json
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/exports/continuation_history.json
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/exports/final_solution.vtu
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/exports/resolved_config.toml
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/exports/run_debug.h5
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/generated_case.toml
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/plots/petsc_deviatoric_strain_3D.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/plots/petsc_displacements_3D.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/plots/petsc_omega_lambda.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/plots/petsc_step_displacement.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric_boundary_edges.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric_corrected_sub1.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric_preview_decim_0p5.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric_preview_decim_0p75.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric_preview_decim_0p9.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric_slice_xmid.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric_slices.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/deviatoric_slices_refined.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/displacement.png
#   benchmarks/3d_hetero_ssr_default/artifacts/simulation/visual_checks/mesh.png

# %% [markdown]
# ## Continuation Summary
#
# MATLAB-style continuation and timing summaries rebuilt from the PETSc artifacts.

# %%
_ = nb.plot_convergence_dashboard(artifacts)
_ = nb.plot_timing_breakdown(artifacts)

# %% [markdown]
# ## 3D Visualizations
#
# These cells use PyVista when the optional `.[viz]` extras are available. In a non-viz environment they
# return a clear status message instead of failing import-time.

# %%
nb.viz_support_status()
# Out:
# {'pyvista': True, 'ipywidgets': True, 'trame': True}

# %%
JUPYTER_BACKEND_OVERRIDE = "client"
SURFACE_SUBDIVISION_OVERRIDE = 2
SURFACE_DECIMATE_REDUCTION_OVERRIDE = 0.0

_ = nb.show_3d_displacement_view(artifacts, ACTIVE_CONFIG, surface_subdivision=SURFACE_SUBDIVISION_OVERRIDE, surface_decimate_reduction=SURFACE_DECIMATE_REDUCTION_OVERRIDE, boundary_edge_overlay=BOUNDARY_EDGE_OVERLAY_OVERRIDE, jupyter_backend=JUPYTER_BACKEND_OVERRIDE)
# Out:
# Widget(value='<iframe src="http://localhost:35875/index.html?ui=P_0x7f777c4e7cb0_0&reconnect=auto" class="pyvi…

# %%
_ = nb.show_3d_deviatoric_surface_view(artifacts, ACTIVE_CONFIG, surface_subdivision=SURFACE_SUBDIVISION_OVERRIDE, surface_decimate_reduction=SURFACE_DECIMATE_REDUCTION_OVERRIDE, boundary_edge_overlay=BOUNDARY_EDGE_OVERLAY_OVERRIDE, jupyter_backend=JUPYTER_BACKEND_OVERRIDE)
# Out:
# Widget(value='<iframe src="http://localhost:35875/index.html?ui=P_0x7f776a053610_1&reconnect=auto" class="pyvi…

# %%
_ = nb.show_3d_deviatoric_slices(
    artifacts,
    ACTIVE_CONFIG,
    slice_planes_x=[],
    slice_planes_y=[35.0],
    slice_planes_z=[43.30127019, 64.95190529],
    clim_scale_max=0.25,
    jupyter_backend=JUPYTER_BACKEND_OVERRIDE,
)
# Out:
# Widget(value='<iframe src="http://localhost:35875/index.html?ui=P_0x7f776a052fd0_2&reconnect=auto" class="pyvi…
